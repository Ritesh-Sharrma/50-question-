# %%
class all_50_questions:
    #1. Prime number
    def prime_number_checker(self,num):
        for i in range(2,num):
            if num%i==0:
                return "Prime Number"
        return "not prime"

    #2. Reverse a string
    def reverse_string(self,string):
        reverse = ""
        for item in string:
            reverse = item + reverse
        return reverse
        
    #3. Palindrome string
    def palindrome_checker(self,num):
        rev = 0
        x = num
        while(num>0):
            rev = (rev*10)+num%10
            num=num//10
        if (x==rev):
            return ("palindrome")
        else:
            return ("not palindrome")

    #4 . Second Largest
    def second_largest_finder(self,list1):
        if len(list1)<1:
            return "enter at least 2 or more values"
        first = second = float('-inf')
        for item in list1:
            if item > first:
                second = first
                first = item
            elif item > second and item != first:
                second = item
        return second 

    #5. Factorial finder
    def factorial_finder(seslf,num):
        fact = 1
        for i in range(1,num+1):
            fact = fact * i 
        return fact
            
        
    #6 . Anagram checker
    def anagram_word_checker(self,str1,str2):
        str1 = str1.lower()
        str2 = str2.lower()

        if len(str1) == len(str2):
            if sorted(str1) == sorted(str2):
                return 'Anagram'
            else:
                return 'Not Anagram'
        else:
            return 'Not Anagram'
            
    #7 . Count of Vowlels in string
    def count_of_vowels(self,string):
        vowels = 'aeiouAEIOU'
        count = 0
        for i in string:
            if i in vowels:
                count+=1
        return count
        
    #8 . Sum of Digit
    def sum_of_digit(self,num):
        total = 0
        for i in str(abs(num)):
            total = int(i) + total
        return total

    #9 . Fibonacci series
    def fibonacci_seris(self,num):
        a,b=0,1
        series = []
        for i in range(1,num+1):
            series.append(a)
            a,b=b,a+b
        return series

    #10 . Remove Duplicates from list
    def remove_duplicates(self,list1):
        list2 = []
        for item in list1:
            if item not in list2:
                list2.append(item)
        return list2

    #11 . Check for leap year
    def check_for_leap_year(self,year):
        if (year%4==0 and year%100!=0) or year%400==0:
            return "Leap year"
        else:
            return "Not leap year"

    #12 . Claculate the power without using ** operator
    def calculate_power(self,x,y):
        result = 1
        for i in range(y):
            result = result * x
        return result
    
    #13 . Generate list of even numbers
    def list_of_even_numbers(self,num):
        list1 = []
        for i in range(num+1):
            if i%2==0:
                list1.append(i)
        return list1

    #14. Binary search implementation
    #15. Reverse a word
    def reverse_word(self,text):
        reverse = ''
        for i in text:
            reverse = i + reverse
        return reverse
            
    #16. claculate GCD
    def GCD(self,a,b):
        while b != 0:
            a,b=b,a%b
        return a

    #17. Convert deecimal to binary
    def decimal_to_binary(self,n):
        s=''
        while(n>0):
            r=n%2
            s=str(r)+s
            n=n//2
        return s

    #18. Factorial using recursion
    def factorial_using_recursion(self,n):
        if n==0:
            return 1

        return n * self.factorial_using_recursion(n-1)

    #19. Largest element in list
    def largest_element_in_list(self,list1):
        first = list1[0]
        for i in list1:
            if i > first:
                first = i
        return first

    #20. Count Charecter in string
    def count_charecter(self,string):
        count_char = {}
        for char in string:
            if char in count_char:
                count_char[char] +=1
            else:
                count_char
        return count_char

    #21 Find intersection of two lists
    def intersection_of_lists(self,list1,list2):
        commen_elements = []
        for item in list1:
            if item in list2 and item not in commen_elements:
                commen_elements.append(item)
        return commen_elements

    #22 Remove all white space from string
    def remove_all_whitespace(self,text):
        return text.replace(" ","")

    #23 Sum of a List of Numbers Using Recursion
    def sum_of_numbers_using_recursion(self,numbers):
        if len(numbers)==0:
            return 0 #0 ka last m hai jab sum hora hai 1 + 2 + 3 + 0  = 6
        return numbers[0] + self.sum_of_numbers_using_recursion(numbers[1:])

    #24 Find all prime numbers up to n:
    def prime_number_upto_n(n):
        prime_num_list = []
        for i in range(2,n):
            if n%i==0:
                prime_num_list.append(i)
        return prime_num_list

    #25 Merge two sorted lists
    #def merge_two_sorted_lissts()

    #30. reverse integer:
    def reverse_integer(num):
        reverse = ''
        for item in num:
            if item not in reverse:
                reverse.append(item)
        return reverse
        
            
            

obj1 = all_50_questions()
print(f'1 . prime number: {obj1.prime_number_checker(27)}')
print(f'2 . reverse string:{obj1.reverse_string("Python")}')
print(f'3 . plaindrome chaecker :{obj1.palindrome_checker(121)}')
print(f'4 . Second largest :{obj1.second_largest_finder([1,2,3,4])}')
print(f'5 . Factorial Finder :{obj1.factorial_finder(5)}')
print(f'6 . Anagram word checker: {obj1.anagram_word_checker('Listen','Silent')}')
print(f'7 . Count of vowels: {obj1.count_of_vowels('Ritesh')}')
print(f'8 . Sum of Digit : {obj1.sum_of_digit(123)}')
print(f'9 . fibonacci series : {obj1.fibonacci_seris(6)}')
print(f'10. Remove duplicates from list:{obj1.remove_duplicates([1,2,2,3,3,4])}')
print(f'11. Check for leap year : {obj1.check_for_leap_year(2024)}')
print(f'12. calculate power without(**): {obj1.calculate_power(2,3)}')
print(f'13. list of even numbers : {obj1.list_of_even_numbers(10)}')
print(f'15. reverse a word:{obj1.reverse_word("Python")}')
print(f'16. Calculate GCD:{obj1.GCD(48,18)}')
print(f'17. Decimal to binary:{obj1.decimal_to_binary(14)}')
print(f'18. Factorial using recursion:{obj1.factorial_using_recursion(5)}')
print(f'19. Largest element in list:{obj1.largest_element_in_list([1,2,3,4,5])}')
print(f'20. count charecter instring:{obj1.count_charecter("apple")}')
print(f'21. intersection of two lists:{obj1.intersection_of_lists([1,2,3,4,5],[3,4,5,6,7])}')
print(f'22. remove all whitespace:{obj1.remove_all_whitespace("Hello World")}')
print(f'23. Sum of numbers using recursion :{obj1.sum_of_numbers_using_recursion([1,2,3])}')
# Out:
# 1 . prime number: Prime Number
# 2 . reverse string:nohtyP
# 3 . plaindrome chaecker :palindrome
# 4 . Second largest :3
# 5 . Factorial Finder :120
# 6 . Anagram word checker: Anagram
# 7 . Count of vowels: 2
# 8 . Sum of Digit : 6
# 9 . fibonacci series : [0, 1, 1, 2, 3, 5]
# 10. Remove duplicates from list:[1, 2, 3, 4]
# 11. Check for leap year : Leap year
# 12. calculate power without(**): 8
# 13. list of even numbers : [0, 2, 4, 6, 8, 10]
# 15. reverse a word:nohtyP
# 16. Calculate GCD:6
# 17. Decimal to binary:1110
# 18. Factorial using recursion:120
# 19. Largest element in list:5
# 20. count charecter instring:{}
# 21. intersection of two lists:[3, 4, 5]
# 22. remove all whitespace:HelloWorld
# 23. Sum of numbers using recursion :6

# %%
    #4 . Second Largest
    def second_largest_finder(list1):
        if len(list1)<1:
            return "enter at least 2 or more values"
        first = second = float('-inf')
        for item in list1:
            if item > first:
                second = first
                first = item
            elif item > second and item != first:
                second = item
        return second
